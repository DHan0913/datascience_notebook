# %% [markdown]
# # Heading 1
# ## Heding 2
# ### Heding 3

# %% [markdown]
# - level 1
#     - level 2
#     - level 2
# - level 1

# %% [markdown]
# ### 테이블
# | 컬럼 1 | 컬럼 2 | 컬럼 3 |
# |--------|--------|--------|
# | 내용 1 | 내용 2 | 내용 3 |

# %% [markdown]
# ### 이미지
# ![image.png](attachment:image.png)

# %%
a = 10 + 20

# %%
a
# Out:
# 30

# %% [markdown]
# 만약에 노트북 셀을 처음부터 순서대로 실행 순서를 맞춰야 할 경우
# Kernel > Restart & Run All 메뉴로 전체 실행 순서를 맞춰주는 것을 추천
